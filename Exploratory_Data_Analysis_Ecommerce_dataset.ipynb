# %% [markdown]
# **Summary of the experiment:** This experiment covers the steps and skills required to perform exploratory data analysis (EDA) in Python. The experiment uses a synthetic e-commerce dataset to demonstrate the process. The first step is to import the necessary libraries, pandas and matplotlib. Then, the data is read from a CSV file and displayed using the df.head() and df.tail() methods. The data types of the columns are checked using df.dtypes and converted to the appropriate format if necessary. Summary statistics are calculated using df.describe(). The data is visualized using bar charts and a line chart. Finally, a summary report is created with all the data analysis insights.

# %%
# !pip install pandas
# !pip install matplotlib

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/project1_df.csv')

# %%
gender_counts=df['Gender'].value_counts()
gender_counts
# Out:
# Gender
# Female    18454
# Other     18450
# Male      18096
# Name: count, dtype: int64

# %%
unique_counts=df['Gender'].unique()
unique_counts
# Out:
# array(['Female', 'Male', 'Other'], dtype=object)

# %%
df.isna().sum()
# Out:
# CID                0
# TID                0
# Gender             0
#                   ..
# Net Amount         0
# Purchase Method    0
# Location           0
# Length: 13, dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.head(5)
# Out:
#       CID         TID  Gender     Age Group        Purchase Date  \
# 0  943146  5876328741  Female         25-45  30/08/2023 20:27:08
# 1  180079  1018503182    Male         25-45  23/02/2024 09:33:46
# 2  337580  3814082218   Other  60 and above  06/03/2022 09:09:50
# 3  180333  1395204173   Other  60 and above  04/11/2020 04:41:57
# 4  447553  8009390577    Male         18-25  31/05/2022 17:00:32
#
#    Product Category Discount Availed    Discount Name  Discount Amount (INR)  \
# 0       Electronics              Yes        FESTIVE50                  64.30
# 1       Electronics              Yes  SEASONALOFFER21                 175.19
# 2          Clothing              Yes  SEASONALOFFER21                 211.54
# 3  Sports & Fitness               No              NaN                   0.00
# 4  Sports & Fitness              Yes         WELCOME5                 439.92
#
#    Gross Amount   Net Amount Purchase Method   Location
# ...

# %%
df.tail(5)
# Out:
#          CID         TID  Gender Age Group        Purchase Date  \
# 8262  999516  6312556210  Female     45-60  17/09/2023 12:42:08
# 8263  198042  1335985311    Male     45-60  15/12/2023 04:28:28
# 8264  446919  8304859288   Other     18-25  31/10/2023 20:12:45
# 8265  243345  5312409986  Female     18-25  27/11/2022 03:36:19
# 8266  802173  5137172195     Oth       NaN                  NaN
#
#      Product Category Discount Availed    Discount Name  \
# 8262      Electronics               No              NaN
# 8263     Toys & Games              Yes  SEASONALOFFER21
# 8264      Electronics              Yes  SEASONALOFFER21
# 8265   Home & Kitchen               No              NaN
# 8266              NaN              NaN              NaN
#
#       Discount Amount (INR)  Gross Amount  Net Amount   Purchase Method  \
# 8262                   0.00     2024.2404   2024.2404  Cash on Delivery
# 8263                  50.67      593.3592    542.6892  Cash on Delivery
# ...

# %%
df.shape
# Out:
# (8267, 13)

# %%
df.drop_duplicates(inplace=True)

# %%
df.columns
# Out:
# Index(['CID', 'TID', 'Gender', 'Age Group', 'Purchase Date',
#        'Product Category', 'Discount Availed', 'Discount Name',
#        'Discount Amount (INR)', 'Gross Amount', 'Net Amount',
#        'Purchase Method', 'Location'],
#       dtype='object')

# %%
df.dtypes
# Out:
# CID                        int64
# TID                        int64
# Gender                    object
# Age Group                 object
# Purchase Date             object
# Product Category          object
# Discount Availed          object
# Discount Name             object
# Discount Amount (INR)    float64
# Gross Amount             float64
# Net Amount               float64
# Purchase Method           object
# Location                  object
# dtype: object

# %%
pd.options.display.max_rows = 6

# %%
df
# Out:
#          CID         TID  Gender     Age Group        Purchase Date  \
# 0     943146  5876328741  Female         25-45  30/08/2023 20:27:08
# 1     180079  1018503182    Male         25-45  23/02/2024 09:33:46
# 2     337580  3814082218   Other  60 and above  06/03/2022 09:09:50
# ...      ...         ...     ...           ...                  ...
# 8264  446919  8304859288   Other         18-25  31/10/2023 20:12:45
# 8265  243345  5312409986  Female         18-25  27/11/2022 03:36:19
# 8266  802173  5137172195     Oth           NaN                  NaN
#
#      Product Category Discount Availed    Discount Name  \
# 0         Electronics              Yes        FESTIVE50
# 1         Electronics              Yes  SEASONALOFFER21
# 2            Clothing              Yes  SEASONALOFFER21
# ...               ...              ...              ...
# 8264      Electronics              Yes  SEASONALOFFER21
# 8265   Home & Kitchen               No              NaN
# ...

# %%
pd.options.display.max_columns = 200

# %%
df
# Out:
#          CID         TID  Gender     Age Group        Purchase Date  \
# 0     943146  5876328741  Female         25-45  30/08/2023 20:27:08
# 1     180079  1018503182    Male         25-45  23/02/2024 09:33:46
# 2     337580  3814082218   Other  60 and above  06/03/2022 09:09:50
# ...      ...         ...     ...           ...                  ...
# 8264  446919  8304859288   Other         18-25  31/10/2023 20:12:45
# 8265  243345  5312409986  Female         18-25  27/11/2022 03:36:19
# 8266  802173  5137172195     Oth           NaN                  NaN
#
#      Product Category Discount Availed    Discount Name  \
# 0         Electronics              Yes        FESTIVE50
# 1         Electronics              Yes  SEASONALOFFER21
# 2            Clothing              Yes  SEASONALOFFER21
# ...               ...              ...              ...
# 8264      Electronics              Yes  SEASONALOFFER21
# 8265   Home & Kitchen               No              NaN
# ...

# %%
df.describe()
# Out:
#                  CID           TID  Discount Amount (INR)  Gross Amount  \
# count    8267.000000  8.267000e+03            8266.000000   8266.000000
# mean   550585.287045  5.544946e+09             137.407923   3006.319053
# std    261665.352829  2.567553e+09             166.158093   1722.118233
# ...              ...           ...                    ...           ...
# 50%    550013.000000  5.572740e+09               0.000000   2990.521650
# 75%    778220.500000  7.733298e+09             279.015000   4318.051062
# max    999996.000000  9.997913e+09             499.990000   8361.225600
#
#         Net Amount
# count  8266.000000
# mean   2868.911130
# std    1728.097928
# ...            ...
# 50%    2836.964500
# 75%    4199.736300
# max    8361.225600
#
# [8 rows x 5 columns]

# %%
df.describe(include='object')
#df.describe(include='number')
# Out:
#         Gender Age Group        Purchase Date Product Category  \
# count     8267      8266                 8266             8266
# unique       4         5                 8266                9
# top     Female     25-45  30/08/2023 20:27:08      Electronics
# freq      2804      3281                    1             2465
#
#        Discount Availed Discount Name Purchase Method Location
# count              8266          4102            8266     8266
# unique                2             5               8       14
# top                  No      NEWYEARS     Credit Card   Mumbai
# freq               4164          1249            3349     1691

# %%
df['Purchase Date'] = pd.to_datetime(df['Purchase Date'], format='%d/%m/%Y %H:%M:%S')

# %%
df.dtypes
# Out:
# CID                  int64
# TID                  int64
# Gender              object
#                     ...
# Net Amount         float64
# Purchase Method     object
# Location            object
# Length: 13, dtype: object

# %%
df_new = df[['CID',
             'TID',
             'Gender',
             'Age Group',
             'Purchase Date',
             'Product Category',
             'Discount Availed',
             'Discount Name',
             'Discount Amount (INR)',
             'Gross Amount',
             'Net Amount',
             'Purchase Method',
             'Location']].copy()

df_new.head()
# Out:
#       CID         TID  Gender     Age Group       Purchase Date  \
# 0  943146  5876328741  Female         25-45 2023-08-30 20:27:08
# 1  180079  1018503182    Male         25-45 2024-02-23 09:33:46
# 2  337580  3814082218   Other  60 and above 2022-03-06 09:09:50
# 3  180333  1395204173   Other  60 and above 2020-11-04 04:41:57
# 4  447553  8009390577    Male         18-25 2022-05-31 17:00:32
#
#    Product Category Discount Availed    Discount Name  Discount Amount (INR)  \
# 0       Electronics              Yes        FESTIVE50                  64.30
# 1       Electronics              Yes  SEASONALOFFER21                 175.19
# 2          Clothing              Yes  SEASONALOFFER21                 211.54
# 3  Sports & Fitness               No              NaN                   0.00
# 4  Sports & Fitness              Yes         WELCOME5                 439.92
#
#    Gross Amount   Net Amount Purchase Method   Location
# 0    725.304000   661.004000     Credit Card  Ahmedabad
# ...

# %%
df_new1=df.drop(['Discount Availed'], axis=1)

# %%
df_new1.columns
# Out:
# Index(['CID', 'TID', 'Gender', 'Age Group', 'Purchase Date',
#        'Product Category', 'Discount Name', 'Discount Amount (INR)',
#        'Gross Amount', 'Net Amount', 'Purchase Method', 'Location'],
#       dtype='object')

# %%
df = df.rename(columns={'CID': 'customer_id',
                        'TID': 'transaction_id',
                        'Gender': 'gender',
                        'Age Group': 'age',
                        'Purchase Date': 'purchase_date',
                        'Product Category': 'product_category',
                        'Discount Availed': 'discount',
                        'Discount Name': 'discount_name',
                        'Discount Amount (INR)': 'discount_amount',
                        'Gross Amount': 'gross_amount',
                        'Net Amount': 'net_amount',
                        'Purchase Method': 'payment_type',
                        'Location': 'location'})

# %%
df.head(5)
# Out:
#    customer_id  transaction_id  gender           age       purchase_date  \
# 0       943146      5876328741  Female         25-45 2023-08-30 20:27:08
# 1       180079      1018503182    Male         25-45 2024-02-23 09:33:46
# 2       337580      3814082218   Other  60 and above 2022-03-06 09:09:50
# 3       180333      1395204173   Other  60 and above 2020-11-04 04:41:57
# 4       447553      8009390577    Male         18-25 2022-05-31 17:00:32
#
#    product_category discount    discount_name  discount_amount  gross_amount  \
# 0       Electronics      Yes        FESTIVE50            64.30    725.304000
# 1       Electronics      Yes  SEASONALOFFER21           175.19   4638.991875
# 2          Clothing      Yes  SEASONALOFFER21           211.54   1986.372575
# 3  Sports & Fitness       No              NaN             0.00   5695.612650
# 4  Sports & Fitness      Yes         WELCOME5           439.92   2292.651500
#
#     net_amount payment_type   location
# ...

# %%
df = pd.read_csv('/content/project1_df.csv')
df
# Out:
#           CID         TID  Gender     Age Group        Purchase Date  \
# 0      943146  5876328741  Female         25-45  30/08/2023 20:27:08
# 1      180079  1018503182    Male         25-45  23/02/2024 09:33:46
# 2      337580  3814082218   Other  60 and above  06/03/2022 09:09:50
# ...       ...         ...     ...           ...                  ...
# 54997  649435  9587323189    Male         45-60  02/08/2024 09:30:44
# 54998  982183  5032564481  Female         45-60  05/08/2020 23:57:56
# 54999  126691  9172953722    Male         25-45  21/07/2022 09:05:18
#
#         Product Category Discount Availed    Discount Name  \
# 0            Electronics              Yes        FESTIVE50
# 1            Electronics              Yes  SEASONALOFFER21
# 2               Clothing              Yes  SEASONALOFFER21
# ...                  ...              ...              ...
# 54997     Home & Kitchen              Yes         NEWYEARS
# ...

# %%
gender_counts=df['Gender'].value_counts()
gender_counts
# Out:
# Gender
# Female    18454
# Other     18450
# Male      18096
# Name: count, dtype: int64

# %%
Age_group_counts=df['Age Group'].value_counts()
Age_group_counts
# Out:
# Age Group
# 25-45           22010
# 18-25           16431
# 45-60           11104
# under 18         2771
# 60 and above     2684
# Name: count, dtype: int64

# %%
product_category_counts=df['Product Category'].value_counts()
product_category_counts
# Out:
# Product Category
# Electronics          16574
# Clothing             10968
# Beauty and Health     8332
#                      ...
# Other                 2171
# Pet Care              1618
# Toys & Games          1529
# Name: count, Length: 9, dtype: int64

# %%
plt.figure(figsize=(14, 8))

plt.subplot(2, 2, 1)
df['Gender'].value_counts().plot(kind='bar', color='skyblue', title='Gender Distribution')
plt.ylabel('Count')

plt.subplot(2, 2, 2)
df['Age Group'].value_counts().plot(kind='bar', color='lightgreen', title='Age Group Distribution')
plt.ylabel('Count')

plt.subplot(2, 2, 3)
df['Product Category'].value_counts().plot(kind='bar', color='lightcoral', title='Product Category Distribution')
plt.ylabel('Count')

plt.subplot(2, 2, 4)
df['Purchase Method'].value_counts().plot(kind='bar', color='orange', title='Payment Method Distribution')
plt.ylabel('Count')

plt.tight_layout()
plt.show()

# %%
# Convert 'Purchase Date' to datetime if it's not already
df['Purchase Date'] = pd.to_datetime(df['Purchase Date'])

# Now you can use the .dt accessor
df['purchase_year_month'] = df['Purchase Date'].dt.to_period('M')
# Out:
# <ipython-input-60-dcb0a1402f77>:2: UserWarning: Parsing dates in %d/%m/%Y %H:%M:%S format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df['Purchase Date'] = pd.to_datetime(df['Purchase Date'])

# %%
purchase_trend = df.groupby('purchase_year_month').size()

# %%
purchase_trend
# Out:
# purchase_year_month
# 2019-09    350
# 2019-10    977
# 2019-11    855
#           ...
# 2024-07    933
# 2024-08    936
# 2024-09    502
# Freq: M, Length: 61, dtype: int64

# %%
plt.figure(figsize=(12, 6))
purchase_trend.plot(kind='line', marker='o', color='blue', title='Purchase Trend Over Time')
plt.xlabel('Purchase Year-Month')
plt.ylabel('Number of Purchases')
plt.grid(True)
plt.xticks(rotation=45)
plt.show()
